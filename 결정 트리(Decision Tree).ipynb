# %% [markdown]
# <a href="https://colab.research.google.com/github/kwanization/Machine_Learning_Study/blob/main/%EA%B2%B0%EC%A0%95%20%ED%8A%B8%EB%A6%AC(Decision%20Tree).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 결정 트리(Decision Tree)
#
#
# *   분류와 회귀에 사용되는 지도 학습 방법
# *   데이터 특성으로 부터 추론된 결정 규칙을 통해 값을 예측
# *   if-then-else 결정 규칙을 통해 데이터 학습
# *   트리의 깊이가 깊을 수록 복잡한 모델
# *   결정 트리 장점
#   *   이해와 해석이 쉽다
#   *   시각화가 용이하다
#   *   많은 데이터 전처리가 필요하지 않다
#   *   수치형과 범주형 데이터 모두를 다룰 수 있다
#   *   ...
#
#
#     *  이건 왜 쓰냐면, 결정을 내려야 할 일이 있을 때 그 과정을 자동화해서 모델로 만들려고
#     *  회귀는 어떻게 결정되냐면, 방개수 많으면 비쌈 > 위치가 강남이면 비쌈 > 지하철역이면 비쌈 > 오래된 집이면 쌈 이렇게 기준을 세분화 해가면서 집값을 예측해볼 수 있음.

# %%
import pandas as pd
import numpy as np
import graphviz
import multiprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris, load_wine, load_breast_cancer
from sklearn.datasets import load_diabetes
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # 분류를 위한 데이터

# %% [markdown]
# ## 붓꽃 데이터
#
# #### 붓꽃 데이터 프레임 이쁘게 정리

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 와인 데이터
#
# #### 와인 데이터 프레임 이쁘게 정리

# %%
wine = load_wine()

# %%
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)
wine_df['target'] = wine.target
wine_df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  target
# 0                            3.92   1065.0       0
# 1                            3.40   1050.0       0
# 2                            3.17   1185.0       0
# 3                            3.45   1480.0       0
# 4                            2.93    735.0       0
# ..                            ...      ...     ...
# 173                          1.74    740.0       2
# 174                          1.56    750.0       2
# 175                          1.56    835.0       2
# 176                          1.62    840.0       2
# 177                          1.60    560.0       2
#
# [178 rows x 14 columns]

# %% [markdown]
# ## 유방암 데이터
#
# #### 유방암 데이터 프레임 이쁘게 정리

# %%
cancer = load_breast_cancer()

# %%
cancer_df = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)
cancer_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# # 회귀를 위한 데이터

# %% [markdown]
# ## 당뇨병 데이터
#
# #### 당뇨병 데이터프레임 이쁘게 정리

# %%
diabetes = load_diabetes()

# %%
diabetes_df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)
diabetes_df['target'] = diabetes.target
diabetes_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %% [markdown]
# # 분류를 해보자
#
#
#
# *   DecisionTreeClassifier 는 분류를 위한 결정트리 모델
# *   두개의 배열 X, y를 입력 받음
#   *   X는 [n_samples, n_features] 크기의 데이터 특성 배열
#   *   y는 [n_samples] 크기의 정답 배열

# %%
X = [[0, 0], [1, 1]]
y = [0, 1]
model = tree.DecisionTreeClassifier()
model = model.fit(X, y)

# %%
model.predict([[2., 2.]])
# 2,2가 어디에 들어갈거 같냐고 물어보는거
# Out:
# array([1])

# %%
model.predict_proba([[2., 2.]])
# 그니까 2.,2. 이게 1쪽에 있을 확률이 100%란 소리임
# 그럼 ([[0.5, 0.5]])는?
# Out:
# array([[0., 1.]])

# %% [markdown]
# ## 붓꽃 데이터 학습

# %% [markdown]
# #### 전처리 없이 학습

# %%
model = DecisionTreeClassifier()

# %%
cross_val_score(
    estimator=model,
    X=iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 1.        , 1.        ])

# %% [markdown]
# #### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeClassifier()
)

# %%
cross_val_score(
    estimator=model,
    X=iris.data, y=iris.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([0.96666667, 0.96666667, 0.9       , 0.93333333, 1.        ])

# %% [markdown]
# #### 근데 전처리 사실 의미 없다. 이전에는 의미가 있었으나, 이거는 단순하게 데이터가 얼마보다 크냐 작냐만 비교하는거임. 비교 기준이 중요함

# %% [markdown]
# #### 학습된 결정 트리 *시각화*

# %%
model = DecisionTreeClassifier()
model.fit(iris.data, iris.target)

# 붓꽃데이터셋으로 결정트리 모델 학습해봄
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# #### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                                feature_names=iris.feature_names,
                                class_names=iris.target_names,
                                filled=True, rounded=True,
                                special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### .dot은 그래프 형식으로 문자열 추출해주는거임 암튼 뭐  이런식으로 이쁘게도 할 수 있다.

# %% [markdown]
# #### 시각화

# %%
n_classes = 3
plot_colors = 'ryb'
plot_step = 0.02

# %% [markdown]
# #### 결정 경계 *시각화*

# %%
plt.figure(figsize=(16, 8))
for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
  X = iris.data[:, pair]
  y = iris.target

  model = DecisionTreeClassifier()
  model = model.fit(X, y)
  plt.subplot(2, 3, pairidx + 1)
  x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
  y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                       np.arange(y_min, y_max, plot_step))
  plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
  Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z = Z.reshape(xx.shape)
  cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
  plt.xlabel(iris.feature_names[pair[0]])
  plt.ylabel(iris.feature_names[pair[1]])

  for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                cmap=plt.cm.RdYlBu, edgecolor='b', s=15)
plt.suptitle("Decision surface")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis('tight')
# Out:
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-35-9f97c9ee94dc>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# (np.float64(0.0),
#  np.float64(7.88),
#  np.float64(-0.9),
#  np.float64(3.4800000000000044))

# %% [markdown]
# #### 하이퍼파라미터 *변경하면서* 결정 경계 변화 확인

# %%
plt.figure(figsize=(16, 8))
for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
  X = iris.data[:, pair]
  y = iris.target

  model = DecisionTreeClassifier(max_depth=2)
  model = model.fit(X, y)
  plt.subplot(2, 3, pairidx + 1)
  x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
  y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                       np.arange(y_min, y_max, plot_step))
  plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
  Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z = Z.reshape(xx.shape)
  cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
  plt.xlabel(iris.feature_names[pair[0]])
  plt.ylabel(iris.feature_names[pair[1]])

  for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                                cmap=plt.cm.RdYlBu, edgecolor='b', s=15)
plt.suptitle("Decision surface")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis('tight')
# Out:
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-36-5cf236bfa8f1>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# (np.float64(0.0),
#  np.float64(7.88),
#  np.float64(-0.9),
#  np.float64(3.4800000000000044))

# %%
plt.figure(figsize=(16, 8))
for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
  X = iris.data[:, pair]
  y = iris.target

  model = DecisionTreeClassifier(max_depth=3)
  model = model.fit(X, y)
  plt.subplot(2, 3, pairidx + 1)
  x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
  y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                       np.arange(y_min, y_max, plot_step))
  plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
  Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z = Z.reshape(xx.shape)
  cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
  plt.xlabel(iris.feature_names[pair[0]])
  plt.ylabel(iris.feature_names[pair[1]])

  for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                                cmap=plt.cm.RdYlBu, edgecolor='b', s=15)
plt.suptitle("Decision surface")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis('tight')
# Out:
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-52-6305d3254465>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# (np.float64(0.0),
#  np.float64(7.88),
#  np.float64(-0.9),
#  np.float64(3.4800000000000044))

# %%
plt.figure(figsize=(16, 8))
for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
  X = iris.data[:, pair]
  y = iris.target

  model = DecisionTreeClassifier(max_depth=4)
  model = model.fit(X, y)
  plt.subplot(2, 3, pairidx + 1)
  x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
  y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                       np.arange(y_min, y_max, plot_step))
  plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
  Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z = Z.reshape(xx.shape)
  cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
  plt.xlabel(iris.feature_names[pair[0]])
  plt.ylabel(iris.feature_names[pair[1]])

  for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                                cmap=plt.cm.RdYlBu, edgecolor='b', s=15)
plt.suptitle("Decision surface")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis('tight')
# Out:
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-53-dab3de0d42d9>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# (np.float64(0.0),
#  np.float64(7.88),
#  np.float64(-0.9),
#  np.float64(3.4800000000000044))

# %%
plt.figure(figsize=(16, 8))
for pairidx, pair in enumerate([[0, 1], [0, 2], [0, 3],
                                [1, 2], [1, 3], [2, 3]]):
  X = iris.data[:, pair]
  y = iris.target

  model = DecisionTreeClassifier(max_depth=5)
  model = model.fit(X, y)
  plt.subplot(2, 3, pairidx + 1)
  x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
  y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
  xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                       np.arange(y_min, y_max, plot_step))
  plt.tight_layout(h_pad=-0.5, w_pad=0.5, pad=2.5)
  Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
  Z = Z.reshape(xx.shape)
  cs = plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu)
  plt.xlabel(iris.feature_names[pair[0]])
  plt.ylabel(iris.feature_names[pair[1]])

  for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
                                cmap=plt.cm.RdYlBu, edgecolor='b', s=15)
plt.suptitle("Decision surface")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis('tight')
# Out:
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# <ipython-input-57-3dcf831213eb>:23: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[idx, 0], X[idx, 1], c=color, label=iris.target_names[i],
# (np.float64(0.0),
#  np.float64(7.88),
#  np.float64(-0.9),
#  np.float64(3.4800000000000044))

# %%
model.get_depth()
# Out:
# 5

# %% [markdown]
# ## 당뇨병 데이터 학습

# %% [markdown]
# #### 전처리 없이 학습

# %%
model = DecisionTreeRegressor()

# %%
cross_val_score(
    estimator=model,
    X=diabetes.data, y=diabetes.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([-0.29669224, -0.03620521, -0.06563813,  0.11059071, -0.12199641])

# %% [markdown]
# #### 전처리 후 학습

# %%
model = make_pipeline(
    StandardScaler(),
    DecisionTreeRegressor()
)

# %%
cross_val_score(
    estimator=model,
    X=diabetes.data, y=diabetes.target,
    cv=5,
    n_jobs=multiprocessing.cpu_count()
)
# Out:
# array([-0.38046048, -0.04124015, -0.08275643,  0.01469571, -0.23644394])

# %% [markdown]
# #### 학습된 결정 트리 시각화

# %%
model = DecisionTreeRegressor()
model.fit(diabetes.data, diabetes.target)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# #### 텍스트를 통한 시각화

# %% [markdown]
# #### plot_tree를 사용한 시각화

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5281267502965208, 0.9761904761904762, 'x[8] <= -0.004\nsquared_error = 5929.885\nsamples = 442\nvalue = 152.133'),
#  Text(0.30106541578808643, 0.9285714285714286, 'x[2] <= 0.006\nsquared_error = 3240.821\nsamples = 218\nvalue = 109.986'),
#  Text(0.4145960830423036, 0.9523809523809523, 'True  '),
#  Text(0.2032444319978914, 0.8809523809523809, 'x[6] <= 0.021\nsquared_error = 2143.968\nsamples = 171\nvalue = 96.31'),
#  Text(0.11488534528202425, 0.8333333333333334, 'x[4] <= 0.063\nsquared_error = 2856.847\nsamples = 87\nvalue = 108.805'),
#  Text(0.08849499209277807, 0.7857142857142857, 'x[1] <= 0.003\nsquared_error = 2496.899\nsamples = 85\nvalue = 105.682'),
#  Text(0.042040063257775435, 0.7380952380952381, 'x[3] <= -0.035\nsquared_error = 2955.72\nsamples = 39\nvalue = 118.846'),
#  Text(0.023721665788086453, 0.6904761904761905, 'x[0] <= -0.051\nsquared_error = 2357.959\nsamples = 21\nvalue = 100.429'),
#  Text(0.008434370057986295, 0.6428571428571429, 'x[3] <= -0.092\nsquared_error = 2049.0\nsamples = 8\nvalue = 133.5'),
#  Text(0.0063257775434897206, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.010542962572482868, 0.5952380952380952, 'x[3] <= -0.05\nsquared_error = 1335.633\nsamples = 7\nvalue = 144.714'),
#  Text(0.0063257775434897206, 0.5476190476190477, 'x[8] <= -0.06\nsquared_error = 401.6\nsamples = 5\nvalue = 162.0'),
#  Text(0.004217185028993147, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.008434370057986295, 0.5, 'x[5] <= -0.035\nsquared_error = 50.75\nsamples = 4\nvalue = 152.5'),
#  Text(0.004217185028993147, 0.4523809523809524, 'x[0] <= -0.089\nsquared_error = 16.0\nsamples = 2\nvalue = 146.0'),
#  Text(0.0021085925144965737, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 150.0'),
#  Text(0.0063257775434897206, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.012651555086979441, 0.4523809523809524, 'x[0] <= -0.075\nsquared_error = 1.0\nsamples = 2\nvalue = 159.0'),
#  Text(0.010542962572482868, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 158.0'),
#  Text(0.014760147601476014, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 160.0'),
#  Text(0.014760147601476014, 0.5476190476190477, 'x[4] <= -0.037\nsquared_error = 1056.25\nsamples = 2\nvalue = 101.5'),
#  Text(0.012651555086979441, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 134.0'),
#  Text(0.01686874011597259, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.03900896151818661, 0.6428571428571429, 'x[4] <= 0.011\nsquared_error = 1460.84\nsamples = 13\nvalue = 80.077'),
#  Text(0.0316288877174486, 0.5952380952380952, 'x[6] <= 0.003\nsquared_error = 366.595\nsamples = 11\nvalue = 66.364'),
#  Text(0.02319451765946231, 0.5476190476190477, 'x[2] <= -0.017\nsquared_error = 164.556\nsamples = 6\nvalue = 79.333'),
#  Text(0.021085925144965736, 0.5, 'x[9] <= -0.049\nsquared_error = 122.56\nsamples = 5\nvalue = 75.8'),
#  Text(0.018977332630469163, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.02319451765946231, 0.4523809523809524, 'x[3] <= -0.071\nsquared_error = 25.688\nsamples = 4\nvalue = 70.75'),
#  Text(0.018977332630469163, 0.40476190476190477, 'x[3] <= -0.106\nsquared_error = 2.25\nsamples = 2\nvalue = 75.5'),
#  Text(0.01686874011597259, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.021085925144965736, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 74.0'),
#  Text(0.027411702688455455, 0.40476190476190477, 'x[7] <= -0.021\nsquared_error = 4.0\nsamples = 2\nvalue = 66.0'),
#  Text(0.025303110173958882, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.02952029520295203, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.025303110173958882, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.040063257775434895, 0.5476190476190477, 'x[2] <= -0.058\nsquared_error = 164.96\nsamples = 5\nvalue = 50.8'),
#  Text(0.03584607274644175, 0.5, 'x[8] <= -0.048\nsquared_error = 27.556\nsamples = 3\nvalue = 60.333'),
#  Text(0.03373748023194518, 0.4523809523809524, 'x[5] <= -0.05\nsquared_error = 1.0\nsamples = 2\nvalue = 64.0'),
#  Text(0.0316288877174486, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.03584607274644175, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.037954665260938325, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.04428044280442804, 0.5, 'x[3] <= -0.059\nsquared_error = 30.25\nsamples = 2\nvalue = 36.5'),
#  Text(0.04217185028993147, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 31.0'),
#  Text(0.04638903531892462, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.04638903531892462, 0.5952380952380952, 'x[2] <= -0.047\nsquared_error = 756.25\nsamples = 2\nvalue = 155.5'),
#  Text(0.04428044280442804, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 183.0'),
#  Text(0.048497627833421195, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 128.0'),
#  Text(0.06035846072746442, 0.6904761904761905, 'x[3] <= -0.03\nsquared_error = 2795.667\nsamples = 18\nvalue = 140.333'),
#  Text(0.05271481286241434, 0.6428571428571429, 'x[0] <= -0.06\nsquared_error = 194.0\nsamples = 3\nvalue = 195.0'),
#  Text(0.050606220347917764, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 214.0'),
#  Text(0.05482340537691091, 0.5952380952380952, 'x[8] <= -0.038\nsquared_error = 20.25\nsamples = 2\nvalue = 185.5'),
#  Text(0.05271481286241434, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 181.0'),
#  Text(0.05693199789140749, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 190.0'),
#  Text(0.0680021085925145, 0.6428571428571429, 'x[6] <= 0.017\nsquared_error = 2598.773\nsamples = 15\nvalue = 129.4'),
#  Text(0.06589351607801792, 0.5952380952380952, 'x[6] <= 0.01\nsquared_error = 2210.454\nsamples = 14\nvalue = 123.214'),
#  Text(0.061149182920400634, 0.5476190476190477, 'x[3] <= 0.032\nsquared_error = 1767.111\nsamples = 9\nvalue = 140.0'),
#  Text(0.05904059040590406, 0.5, 'x[9] <= -0.028\nsquared_error = 848.938\nsamples = 8\nvalue = 151.25'),
#  Text(0.05376910911966262, 0.4523809523809524, 'x[2] <= -0.06\nsquared_error = 289.0\nsamples = 2\nvalue = 118.0'),
#  Text(0.05166051660516605, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 101.0'),
#  Text(0.0558777016341592, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.06431207169214549, 0.4523809523809524, 'x[8] <= -0.037\nsquared_error = 544.222\nsamples = 6\nvalue = 162.333'),
#  Text(0.060094886663152346, 0.40476190476190477, 'x[7] <= -0.021\nsquared_error = 178.667\nsamples = 3\nvalue = 182.0'),
#  Text(0.05798629414865577, 0.35714285714285715, 'x[2] <= -0.028\nsquared_error = 25.0\nsamples = 2\nvalue = 173.0'),
#  Text(0.0558777016341592, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.060094886663152346, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.06220347917764892, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.06852925672113865, 0.40476190476190477, 'x[0] <= 0.051\nsquared_error = 136.222\nsamples = 3\nvalue = 142.667'),
#  Text(0.06642066420664207, 0.35714285714285715, 'x[6] <= -0.023\nsquared_error = 20.25\nsamples = 2\nvalue = 150.5'),
#  Text(0.06431207169214549, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 146.0'),
#  Text(0.06852925672113865, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.07063784923563521, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 127.0'),
#  Text(0.0632577754348972, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 50.0'),
#  Text(0.07063784923563521, 0.5476190476190477, 'x[4] <= -0.029\nsquared_error = 1588.4\nsamples = 5\nvalue = 93.0'),
#  Text(0.06852925672113865, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 25.0'),
#  Text(0.07274644175013179, 0.5, 'x[9] <= -0.028\nsquared_error = 540.5\nsamples = 4\nvalue = 110.0'),
#  Text(0.07063784923563521, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.07485503426462836, 0.4523809523809524, 'x[2] <= -0.052\nsquared_error = 206.889\nsamples = 3\nvalue = 98.667'),
#  Text(0.07274644175013179, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 79.0'),
#  Text(0.07696362677912494, 0.40476190476190477, 'x[0] <= -0.056\nsquared_error = 20.25\nsamples = 2\nvalue = 108.5'),
#  Text(0.07485503426462836, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 113.0'),
#  Text(0.0790722192936215, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.07011070110701106, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 216.0'),
#  Text(0.13494992092778071, 0.7380952380952381, 'x[9] <= -0.028\nsquared_error = 1836.423\nsamples = 46\nvalue = 94.522'),
#  Text(0.09804955192409066, 0.6904761904761905, 'x[2] <= -0.047\nsquared_error = 544.506\nsamples = 18\nvalue = 74.222'),
#  Text(0.09172377438060095, 0.6428571428571429, 'x[4] <= -0.041\nsquared_error = 576.609\nsamples = 8\nvalue = 88.875'),
#  Text(0.08961518186610437, 0.5952380952380952, 'x[8] <= -0.062\nsquared_error = 264.98\nsamples = 7\nvalue = 81.857'),
#  Text(0.08328940432261465, 0.5476190476190477, 'x[8] <= -0.087\nsquared_error = 99.5\nsamples = 4\nvalue = 70.0'),
#  Text(0.08118081180811808, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.08539799683711123, 0.5, 'x[0] <= -0.049\nsquared_error = 32.667\nsamples = 3\nvalue = 75.0'),
#  Text(0.08328940432261465, 0.4523809523809524, 'x[4] <= -0.08\nsquared_error = 1.0\nsamples = 2\nvalue = 71.0'),
#  Text(0.08118081180811808, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.08539799683711123, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.08750658935160781, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 83.0'),
#  Text(0.0959409594095941, 0.5476190476190477, 'x[7] <= 0.016\nsquared_error = 48.222\nsamples = 3\nvalue = 97.667'),
#  Text(0.09383236689509752, 0.5, 'x[5] <= -0.046\nsquared_error = 2.25\nsamples = 2\nvalue = 102.5'),
#  Text(0.09172377438060095, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 101.0'),
#  Text(0.0959409594095941, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.09804955192409066, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.09383236689509752, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 138.0'),
#  Text(0.1043753294675804, 0.6428571428571429, 'x[2] <= -0.008\nsquared_error = 209.65\nsamples = 10\nvalue = 62.5'),
#  Text(0.10226673695308382, 0.5952380952380952, 'x[8] <= -0.099\nsquared_error = 125.506\nsamples = 9\nvalue = 59.222'),
#  Text(0.10015814443858724, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 78.0'),
#  Text(0.1043753294675804, 0.5476190476190477, 'x[4] <= -0.072\nsquared_error = 91.609\nsamples = 8\nvalue = 56.875'),
#  Text(0.10226673695308382, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 71.0'),
#  Text(0.10648392198207696, 0.5, 'x[6] <= -0.021\nsquared_error = 33.472\nsamples = 6\nvalue = 52.167'),
#  Text(0.10121244069583553, 0.4523809523809524, 'x[2] <= -0.021\nsquared_error = 9.0\nsamples = 2\nvalue = 58.0'),
#  Text(0.09910384818133895, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.1033210332103321, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.1117554032683184, 0.4523809523809524, 'x[8] <= -0.036\nsquared_error = 20.188\nsamples = 4\nvalue = 49.25'),
#  Text(0.10753821823932525, 0.40476190476190477, 'x[4] <= -0.048\nsquared_error = 4.0\nsamples = 2\nvalue = 45.0'),
#  Text(0.10542962572482868, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 43.0'),
#  Text(0.10964681075382182, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 47.0'),
#  Text(0.11597258829731154, 0.40476190476190477, 'x[8] <= -0.022\nsquared_error = 0.25\nsamples = 2\nvalue = 53.5'),
#  Text(0.11386399578281498, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 54.0'),
#  Text(0.11808118081180811, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.10648392198207696, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 92.0'),
#  Text(0.17185028993147075, 0.6904761904761905, 'x[6] <= 0.003\nsquared_error = 2231.745\nsamples = 28\nvalue = 107.571'),
#  Text(0.1528729573010016, 0.6428571428571429, 'x[0] <= 0.08\nsquared_error = 1452.45\nsamples = 20\nvalue = 95.5'),
#  Text(0.150764364786505, 0.5952380952380952, 'x[2] <= -0.012\nsquared_error = 935.418\nsamples = 19\nvalue = 90.053'),
#  Text(0.1370585134422773, 0.5476190476190477, 'x[5] <= -0.023\nsquared_error = 890.329\nsamples = 15\nvalue = 97.267'),
#  Text(0.12862414338429098, 0.5, 'x[6] <= -0.007\nsquared_error = 1023.5\nsamples = 4\nvalue = 121.0'),
#  Text(0.1265155508697944, 0.4523809523809524, 'x[5] <= -0.029\nsquared_error = 253.556\nsamples = 3\nvalue = 137.667'),
#  Text(0.12440695835529784, 0.40476190476190477, 'x[9] <= 0.018\nsquared_error = 6.25\nsamples = 2\nvalue = 126.5'),
#  Text(0.12229836584080127, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 129.0'),
#  Text(0.1265155508697944, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 124.0'),
#  Text(0.12862414338429098, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 160.0'),
#  Text(0.13073273589878756, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.14549288350026357, 0.5, 'x[2] <= -0.022\nsquared_error = 562.595\nsamples = 11\nvalue = 88.636'),
#  Text(0.1370585134422773, 0.4523809523809524, 'x[0] <= 0.033\nsquared_error = 237.0\nsamples = 4\nvalue = 66.0'),
#  Text(0.13284132841328414, 0.40476190476190477, 'x[3] <= -0.035\nsquared_error = 1.0\nsamples = 2\nvalue = 52.0'),
#  Text(0.13073273589878756, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.13494992092778071, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.14127569847127042, 0.40476190476190477, 'x[4] <= 0.001\nsquared_error = 81.0\nsamples = 2\nvalue = 80.0'),
#  Text(0.13916710595677384, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.143384290985767, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 89.0'),
#  Text(0.15392725355824988, 0.4523809523809524, 'x[5] <= -0.015\nsquared_error = 288.531\nsamples = 7\nvalue = 101.571'),
#  Text(0.14971006852925672, 0.40476190476190477, 'x[2] <= -0.016\nsquared_error = 9.0\nsamples = 2\nvalue = 80.0'),
#  Text(0.14760147601476015, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.1518186610437533, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 83.0'),
#  Text(0.158144438587243, 0.40476190476190477, 'x[5] <= -0.003\nsquared_error = 139.76\nsamples = 5\nvalue = 110.2'),
#  Text(0.15603584607274645, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 132.0'),
#  Text(0.16025303110173958, 0.35714285714285715, 'x[4] <= 0.014\nsquared_error = 26.188\nsamples = 4\nvalue = 104.75'),
#  Text(0.158144438587243, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.16236162361623616, 0.30952380952380953, 'x[8] <= -0.009\nsquared_error = 8.222\nsamples = 3\nvalue = 107.333'),
#  Text(0.16025303110173958, 0.2619047619047619, 'x[5] <= 0.064\nsquared_error = 2.25\nsamples = 2\nvalue = 105.5'),
#  Text(0.158144438587243, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 107.0'),
#  Text(0.16236162361623616, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.16447021613073273, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 111.0'),
#  Text(0.16447021613073273, 0.5476190476190477, 'x[9] <= 0.022\nsquared_error = 177.5\nsamples = 4\nvalue = 63.0'),
#  Text(0.16025303110173958, 0.5, 'x[0] <= -0.033\nsquared_error = 64.0\nsamples = 2\nvalue = 52.0'),
#  Text(0.158144438587243, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.16236162361623616, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 44.0'),
#  Text(0.16868740115972589, 0.5, 'x[4] <= -0.036\nsquared_error = 49.0\nsamples = 2\nvalue = 74.0'),
#  Text(0.1665788086452293, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 67.0'),
#  Text(0.17079599367422246, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.15498154981549817, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 199.0'),
#  Text(0.1908276225619399, 0.6428571428571429, 'x[3] <= 0.003\nsquared_error = 2904.938\nsamples = 8\nvalue = 137.75'),
#  Text(0.1834475487612019, 0.5952380952380952, 'x[2] <= -0.029\nsquared_error = 908.56\nsamples = 5\nvalue = 101.2'),
#  Text(0.17923036373220874, 0.5476190476190477, 'x[6] <= 0.016\nsquared_error = 72.667\nsamples = 3\nvalue = 123.0'),
#  Text(0.17712177121771217, 0.5, 'x[3] <= -0.025\nsquared_error = 1.0\nsamples = 2\nvalue = 117.0'),
#  Text(0.17501317870321562, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 116.0'),
#  Text(0.17923036373220874, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.18133895624670532, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 135.0'),
#  Text(0.18766473379019505, 0.5476190476190477, 'x[8] <= -0.045\nsquared_error = 380.25\nsamples = 2\nvalue = 68.5'),
#  Text(0.18555614127569847, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.18977332630469163, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.1982076963626779, 0.5952380952380952, 'x[4] <= -0.006\nsquared_error = 294.889\nsamples = 3\nvalue = 198.667'),
#  Text(0.19609910384818133, 0.5476190476190477, 'x[2] <= -0.022\nsquared_error = 90.25\nsamples = 2\nvalue = 209.5'),
#  Text(0.19399051133368478, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.1982076963626779, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 219.0'),
#  Text(0.20031628887717448, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 177.0'),
#  Text(0.14127569847127042, 0.7857142857142857, 'x[6] <= -0.014\nsquared_error = 132.25\nsamples = 2\nvalue = 241.5'),
#  Text(0.13916710595677384, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 253.0'),
#  Text(0.143384290985767, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(0.29160351871375856, 0.8333333333333334, 'x[1] <= 0.003\nsquared_error = 1076.471\nsamples = 84\nvalue = 83.369'),
#  Text(0.2500494201370585, 0.7857142857142857, 'x[2] <= -0.063\nsquared_error = 1193.75\nsamples = 64\nvalue = 88.0'),
#  Text(0.2076963626779125, 0.7380952380952381, 'x[0] <= -0.1\nsquared_error = 645.673\nsamples = 14\nvalue = 68.571'),
#  Text(0.20558777016341592, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 137.0'),
#  Text(0.20980495519240908, 0.6904761904761905, 'x[8] <= -0.065\nsquared_error = 307.444\nsamples = 13\nvalue = 63.308'),
#  Text(0.20453347390616763, 0.6428571428571429, 'x[5] <= -0.051\nsquared_error = 6.25\nsamples = 2\nvalue = 87.5'),
#  Text(0.20242488139167106, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.2066420664206642, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.2150764364786505, 0.6428571428571429, 'x[3] <= -0.083\nsquared_error = 236.446\nsamples = 11\nvalue = 58.909'),
#  Text(0.21085925144965736, 0.5952380952380952, 'x[4] <= -0.02\nsquared_error = 144.0\nsamples = 2\nvalue = 84.0'),
#  Text(0.2087506589351608, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.2129678439641539, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.21929362150764364, 0.5952380952380952, 'x[0] <= 0.029\nsquared_error = 86.0\nsamples = 9\nvalue = 53.333'),
#  Text(0.21718502899314707, 0.5476190476190477, 'x[2] <= -0.064\nsquared_error = 47.75\nsamples = 8\nvalue = 51.0'),
#  Text(0.2150764364786505, 0.5, 'x[2] <= -0.068\nsquared_error = 22.571\nsamples = 7\nvalue = 53.0'),
#  Text(0.2129678439641539, 0.4523809523809524, 'x[3] <= -0.066\nsquared_error = 11.44\nsamples = 5\nvalue = 50.6'),
#  Text(0.21085925144965736, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 57.0'),
#  Text(0.2150764364786505, 0.40476190476190477, 'x[2] <= -0.078\nsquared_error = 1.5\nsamples = 4\nvalue = 49.0'),
#  Text(0.2129678439641539, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.21718502899314707, 0.35714285714285715, 'x[5] <= -0.005\nsquared_error = 0.222\nsamples = 3\nvalue = 48.333'),
#  Text(0.2150764364786505, 0.30952380952380953, 'squared_error = 0.0\nsamples = 2\nvalue = 48.0'),
#  Text(0.21929362150764364, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.21718502899314707, 0.4523809523809524, 'squared_error = 0.0\nsamples = 2\nvalue = 59.0'),
#  Text(0.21929362150764364, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 37.0'),
#  Text(0.22140221402214022, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.2924024775962045, 0.7380952380952381, 'x[3] <= 0.025\nsquared_error = 1211.926\nsamples = 50\nvalue = 93.44'),
#  Text(0.2801133368476542, 0.6904761904761905, 'x[2] <= -0.013\nsquared_error = 1092.947\nsamples = 48\nvalue = 91.396'),
#  Text(0.2618608328940432, 0.6428571428571429, 'x[8] <= -0.011\nsquared_error = 1086.812\nsamples = 38\nvalue = 97.632'),
#  Text(0.24538745387453875, 0.5952380952380952, 'x[0] <= -0.04\nsquared_error = 954.217\nsamples = 35\nvalue = 94.2'),
#  Text(0.22878228782287824, 0.5476190476190477, 'x[4] <= -0.072\nsquared_error = 442.222\nsamples = 9\nvalue = 114.333'),
#  Text(0.2235108065366368, 0.5, 'x[3] <= -0.054\nsquared_error = 20.25\nsamples = 2\nvalue = 147.5'),
#  Text(0.22140221402214022, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 152.0'),
#  Text(0.22561939905113337, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 143.0'),
#  Text(0.23405376910911965, 0.5, 'x[2] <= -0.044\nsquared_error = 158.694\nsamples = 7\nvalue = 104.857'),
#  Text(0.22983658408012653, 0.4523809523809524, 'x[6] <= 0.076\nsquared_error = 107.188\nsamples = 4\nvalue = 113.25'),
#  Text(0.22772799156562995, 0.40476190476190477, 'x[0] <= -0.071\nsquared_error = 46.222\nsamples = 3\nvalue = 108.333'),
#  Text(0.22561939905113337, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 99.0'),
#  Text(0.22983658408012653, 0.35714285714285715, 'x[4] <= -0.003\nsquared_error = 4.0\nsamples = 2\nvalue = 113.0'),
#  Text(0.22772799156562995, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 115.0'),
#  Text(0.23194517659462308, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 111.0'),
#  Text(0.23194517659462308, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 128.0'),
#  Text(0.2382709541381128, 0.4523809523809524, 'x[6] <= 0.063\nsquared_error = 8.222\nsamples = 3\nvalue = 93.667'),
#  Text(0.23616236162361623, 0.40476190476190477, 'x[5] <= -0.019\nsquared_error = 2.25\nsamples = 2\nvalue = 95.5'),
#  Text(0.23405376910911965, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.2382709541381128, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 94.0'),
#  Text(0.24037954665260938, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.26199261992619927, 0.5476190476190477, 'x[2] <= -0.03\nsquared_error = 942.562\nsamples = 26\nvalue = 87.231'),
#  Text(0.24986821296784398, 0.5, 'x[4] <= 0.049\nsquared_error = 705.627\nsamples = 20\nvalue = 80.65'),
#  Text(0.2477596204533474, 0.4523809523809524, 'x[6] <= 0.027\nsquared_error = 411.296\nsamples = 19\nvalue = 76.579'),
#  Text(0.24565102793885082, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 40.0'),
#  Text(0.24986821296784398, 0.40476190476190477, 'x[4] <= -0.055\nsquared_error = 355.682\nsamples = 18\nvalue = 78.611'),
#  Text(0.24248813916710596, 0.35714285714285715, 'x[9] <= -0.105\nsquared_error = 30.25\nsamples = 2\nvalue = 119.5'),
#  Text(0.24037954665260938, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 125.0'),
#  Text(0.24459673168160254, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 114.0'),
#  Text(0.25724828676858197, 0.35714285714285715, 'x[0] <= 0.004\nsquared_error = 161.25\nsamples = 16\nvalue = 73.5'),
#  Text(0.2488139167105957, 0.30952380952380953, 'x[2] <= -0.037\nsquared_error = 55.633\nsamples = 7\nvalue = 65.714'),
#  Text(0.2467053241960991, 0.2619047619047619, 'x[5] <= -0.025\nsquared_error = 28.333\nsamples = 6\nvalue = 68.0'),
#  Text(0.24248813916710596, 0.21428571428571427, 'x[8] <= -0.02\nsquared_error = 4.667\nsamples = 3\nvalue = 63.0'),
#  Text(0.24037954665260938, 0.16666666666666666, 'x[0] <= -0.016\nsquared_error = 0.25\nsamples = 2\nvalue = 64.5'),
#  Text(0.2382709541381128, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.24248813916710596, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.24459673168160254, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.25092250922509224, 0.21428571428571427, 'x[8] <= -0.06\nsquared_error = 2.0\nsamples = 3\nvalue = 73.0'),
#  Text(0.2488139167105957, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.2530311017395888, 0.16666666666666666, 'squared_error = 0.0\nsamples = 2\nvalue = 72.0'),
#  Text(0.25092250922509224, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.2656826568265683, 0.30952380952380953, 'x[0] <= 0.018\nsquared_error = 159.58\nsamples = 9\nvalue = 79.556'),
#  Text(0.2614654717975751, 0.2619047619047619, 'x[8] <= -0.027\nsquared_error = 14.0\nsamples = 3\nvalue = 92.0'),
#  Text(0.25935687928307855, 0.21428571428571427, 'x[9] <= -0.009\nsquared_error = 2.25\nsamples = 2\nvalue = 94.5'),
#  Text(0.25724828676858197, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.2614654717975751, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 93.0'),
#  Text(0.2635740643120717, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.26989984185556143, 0.2619047619047619, 'x[2] <= -0.06\nsquared_error = 116.222\nsamples = 6\nvalue = 73.333'),
#  Text(0.26779124934106485, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 89.0'),
#  Text(0.272008434370058, 0.21428571428571427, 'x[3] <= -0.009\nsquared_error = 80.56\nsamples = 5\nvalue = 70.2'),
#  Text(0.26989984185556143, 0.16666666666666666, 'x[3] <= -0.019\nsquared_error = 12.5\nsamples = 4\nvalue = 66.0'),
#  Text(0.26779124934106485, 0.11904761904761904, 'x[6] <= 0.089\nsquared_error = 0.667\nsamples = 3\nvalue = 64.0'),
#  Text(0.2656826568265683, 0.07142857142857142, 'x[4] <= 0.022\nsquared_error = 0.25\nsamples = 2\nvalue = 63.5'),
#  Text(0.2635740643120717, 0.023809523809523808, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.26779124934106485, 0.023809523809523808, 'squared_error = 0.0\nsamples = 1\nvalue = 64.0'),
#  Text(0.26989984185556143, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.272008434370058, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 72.0'),
#  Text(0.2741170268845546, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 87.0'),
#  Text(0.2519768054823405, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 158.0'),
#  Text(0.2741170268845546, 0.5, 'x[6] <= 0.058\nsquared_error = 1106.806\nsamples = 6\nvalue = 109.167'),
#  Text(0.272008434370058, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 179.0'),
#  Text(0.27622561939905116, 0.4523809523809524, 'x[3] <= -0.019\nsquared_error = 157.76\nsamples = 5\nvalue = 95.2'),
#  Text(0.2741170268845546, 0.40476190476190477, 'x[7] <= -0.074\nsquared_error = 34.75\nsamples = 4\nvalue = 89.5'),
#  Text(0.272008434370058, 0.35714285714285715, 'x[2] <= -0.025\nsquared_error = 9.0\nsamples = 2\nvalue = 95.0'),
#  Text(0.26989984185556143, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 98.0'),
#  Text(0.2741170268845546, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 92.0'),
#  Text(0.27622561939905116, 0.35714285714285715, 'squared_error = 0.0\nsamples = 2\nvalue = 84.0'),
#  Text(0.2783342119135477, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.2783342119135477, 0.5952380952380952, 'x[3] <= -0.047\nsquared_error = 893.556\nsamples = 3\nvalue = 137.667'),
#  Text(0.27622561939905116, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 97.0'),
#  Text(0.28044280442804426, 0.5476190476190477, 'x[4] <= -0.004\nsquared_error = 100.0\nsamples = 2\nvalue = 158.0'),
#  Text(0.2783342119135477, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 148.0'),
#  Text(0.28255139694254083, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 168.0'),
#  Text(0.29836584080126516, 0.6428571428571429, 'x[8] <= -0.038\nsquared_error = 407.01\nsamples = 10\nvalue = 67.7'),
#  Text(0.2930943595150237, 0.5952380952380952, 'x[4] <= 0.022\nsquared_error = 177.889\nsamples = 6\nvalue = 59.667'),
#  Text(0.29098576700052714, 0.5476190476190477, 'x[0] <= -0.007\nsquared_error = 104.24\nsamples = 5\nvalue = 55.4'),
#  Text(0.286768581971534, 0.5, 'x[6] <= 0.038\nsquared_error = 12.667\nsamples = 3\nvalue = 63.0'),
#  Text(0.2846599894570374, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 68.0'),
#  Text(0.28887717448603056, 0.4523809523809524, 'x[9] <= -0.038\nsquared_error = 0.25\nsamples = 2\nvalue = 60.5'),
#  Text(0.286768581971534, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 60.0'),
#  Text(0.29098576700052714, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 61.0'),
#  Text(0.2952029520295203, 0.5, 'x[8] <= -0.063\nsquared_error = 25.0\nsamples = 2\nvalue = 44.0'),
#  Text(0.2930943595150237, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 39.0'),
#  Text(0.29731154454401687, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 49.0'),
#  Text(0.2952029520295203, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 81.0'),
#  Text(0.3036373220875066, 0.5952380952380952, 'x[5] <= 0.009\nsquared_error = 508.688\nsamples = 4\nvalue = 79.75'),
#  Text(0.30152872957301, 0.5476190476190477, 'x[3] <= -0.016\nsquared_error = 156.25\nsamples = 2\nvalue = 100.5'),
#  Text(0.29942013705851345, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 113.0'),
#  Text(0.3036373220875066, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 88.0'),
#  Text(0.3057459146020032, 0.5476190476190477, 'squared_error = 0.0\nsamples = 2\nvalue = 59.0'),
#  Text(0.3046916183447549, 0.6904761904761905, 'x[6] <= 0.115\nsquared_error = 1560.25\nsamples = 2\nvalue = 142.5'),
#  Text(0.3025830258302583, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.30680021085925147, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 103.0'),
#  Text(0.3331576172904586, 0.7857142857142857, 'x[0] <= 0.005\nsquared_error = 412.948\nsamples = 20\nvalue = 68.55'),
#  Text(0.32050606220347916, 0.7380952380952381, 'x[6] <= 0.034\nsquared_error = 145.16\nsamples = 10\nvalue = 55.8'),
#  Text(0.3131259884027412, 0.6904761904761905, 'x[9] <= -0.038\nsquared_error = 24.0\nsamples = 3\nvalue = 71.0'),
#  Text(0.3110173958882446, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.3152345809172377, 0.6428571428571429, 'x[0] <= -0.015\nsquared_error = 9.0\nsamples = 2\nvalue = 68.0'),
#  Text(0.3131259884027412, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 71.0'),
#  Text(0.3173431734317343, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 65.0'),
#  Text(0.3278861360042172, 0.6904761904761905, 'x[0] <= -0.031\nsquared_error = 55.633\nsamples = 7\nvalue = 49.286'),
#  Text(0.323668950975224, 0.6428571428571429, 'x[5] <= -0.022\nsquared_error = 6.0\nsamples = 3\nvalue = 42.0'),
#  Text(0.32156035846072745, 0.5952380952380952, 'x[6] <= 0.08\nsquared_error = 2.25\nsamples = 2\nvalue = 43.5'),
#  Text(0.31945176594623087, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 42.0'),
#  Text(0.323668950975224, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 45.0'),
#  Text(0.3257775434897206, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 39.0'),
#  Text(0.33210332103321033, 0.6428571428571429, 'x[8] <= -0.014\nsquared_error = 23.188\nsamples = 4\nvalue = 54.75'),
#  Text(0.32999472851871375, 0.5952380952380952, 'x[9] <= -0.057\nsquared_error = 0.667\nsamples = 3\nvalue = 52.0'),
#  Text(0.3278861360042172, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 51.0'),
#  Text(0.33210332103321033, 0.5476190476190477, 'x[2] <= -0.012\nsquared_error = 0.25\nsamples = 2\nvalue = 52.5'),
#  Text(0.32999472851871375, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 53.0'),
#  Text(0.3342119135477069, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.3342119135477069, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.3458091723774381, 0.7380952380952381, 'x[9] <= 0.005\nsquared_error = 355.61\nsamples = 10\nvalue = 81.3'),
#  Text(0.34053769109119664, 0.6904761904761905, 'x[8] <= -0.083\nsquared_error = 171.061\nsamples = 7\nvalue = 71.286'),
#  Text(0.33842909857670006, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 47.0'),
#  Text(0.3426462836056932, 0.6428571428571429, 'x[9] <= -0.009\nsquared_error = 84.889\nsamples = 6\nvalue = 75.333'),
#  Text(0.33842909857670006, 0.5952380952380952, 'x[9] <= -0.049\nsquared_error = 38.188\nsamples = 4\nvalue = 80.75'),
#  Text(0.3363205060622035, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 91.0'),
#  Text(0.34053769109119664, 0.5476190476190477, 'x[6] <= 0.039\nsquared_error = 4.222\nsamples = 3\nvalue = 77.333'),
#  Text(0.33842909857670006, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 80.0'),
#  Text(0.3426462836056932, 0.5, 'x[0] <= 0.04\nsquared_error = 1.0\nsamples = 2\nvalue = 76.0'),
#  Text(0.34053769109119664, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 77.0'),
#  Text(0.3447548761201898, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 75.0'),
#  Text(0.34686346863468637, 0.5952380952380952, 'x[4] <= 0.027\nsquared_error = 2.25\nsamples = 2\nvalue = 64.5'),
#  Text(0.3447548761201898, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 66.0'),
#  Text(0.34897206114918294, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 63.0'),
#  Text(0.3510806536636795, 0.6904761904761905, 'x[9] <= 0.011\nsquared_error = 6.222\nsamples = 3\nvalue = 104.667'),
#  Text(0.34897206114918294, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 108.0'),
#  Text(0.35318924617817604, 0.6428571428571429, 'x[5] <= -0.02\nsquared_error = 1.0\nsamples = 2\nvalue = 103.0'),
#  Text(0.3510806536636795, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 104.0'),
#  Text(0.3552978386926726, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 102.0'),
#  Text(0.3988863995782815, 0.8809523809523809, 'x[0] <= -0.08\nsquared_error = 4075.084\nsamples = 47\nvalue = 159.745'),
#  Text(0.37915129151291516, 0.8333333333333334, 'x[4] <= 0.021\nsquared_error = 784.0\nsamples = 2\nvalue = 274.0'),
#  Text(0.3770426989984186, 0.7857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.3812598840274117, 0.7857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 302.0'),
#  Text(0.41862150764364786, 0.8333333333333334, 'x[3] <= 0.01\nsquared_error = 3615.378\nsamples = 45\nvalue = 154.667'),
#  Text(0.38547706905640483, 0.7857142857142857, 'x[4] <= -0.048\nsquared_error = 1713.249\nsamples = 26\nvalue = 135.538'),
#  Text(0.3658408012651555, 0.7380952380952381, 'x[3] <= -0.045\nsquared_error = 782.222\nsamples = 6\nvalue = 176.333'),
#  Text(0.35951502372166577, 0.6904761904761905, 'x[4] <= -0.068\nsquared_error = 136.222\nsamples = 3\nvalue = 197.667'),
#  Text(0.3574064312071692, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.36162361623616235, 0.6428571428571429, 'x[5] <= -0.035\nsquared_error = 20.25\nsamples = 2\nvalue = 205.5'),
#  Text(0.35951502372166577, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 210.0'),
#  Text(0.3637322087506589, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 201.0'),
#  Text(0.37216657880864523, 0.6904761904761905, 'x[3] <= -0.023\nsquared_error = 518.0\nsamples = 3\nvalue = 155.0'),
#  Text(0.37005798629414866, 0.6428571428571429, 'x[0] <= -0.024\nsquared_error = 9.0\nsamples = 2\nvalue = 139.0'),
#  Text(0.3679493937796521, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 142.0'),
#  Text(0.37216657880864523, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 136.0'),
#  Text(0.3742751713231418, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 187.0'),
#  Text(0.4051133368476542, 0.7380952380952381, 'x[5] <= 0.043\nsquared_error = 1343.51\nsamples = 20\nvalue = 123.3'),
#  Text(0.3937796520822351, 0.6904761904761905, 'x[6] <= 0.001\nsquared_error = 1257.059\nsamples = 17\nvalue = 130.0'),
#  Text(0.3827095413811281, 0.6428571428571429, 'x[0] <= 0.009\nsquared_error = 461.109\nsamples = 8\nvalue = 151.125'),
#  Text(0.3763837638376384, 0.5952380952380952, 'x[2] <= 0.039\nsquared_error = 178.25\nsamples = 4\nvalue = 167.5'),
#  Text(0.3742751713231418, 0.5476190476190477, 'x[4] <= -0.028\nsquared_error = 50.889\nsamples = 3\nvalue = 174.333'),
#  Text(0.37216657880864523, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 184.0'),
#  Text(0.3763837638376384, 0.5, 'x[9] <= 0.013\nsquared_error = 6.25\nsamples = 2\nvalue = 169.5'),
#  Text(0.3742751713231418, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 172.0'),
#  Text(0.37849235635213496, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 167.0'),
#  Text(0.37849235635213496, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 147.0'),
#  Text(0.3890353189246178, 0.5952380952380952, 'x[0] <= 0.038\nsquared_error = 207.688\nsamples = 4\nvalue = 134.75'),
#  Text(0.38692672641012127, 0.5476190476190477, 'x[6] <= -0.04\nsquared_error = 4.667\nsamples = 3\nvalue = 143.0'),
#  Text(0.3848181338956247, 0.5, 'x[1] <= 0.003\nsquared_error = 0.25\nsamples = 2\nvalue = 144.5'),
#  Text(0.3827095413811281, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 144.0'),
#  Text(0.38692672641012127, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 145.0'),
#  Text(0.3890353189246178, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.39114391143911437, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 110.0'),
#  Text(0.4048497627833421, 0.6428571428571429, 'x[3] <= -0.001\nsquared_error = 1215.284\nsamples = 9\nvalue = 111.222'),
#  Text(0.3974696889826041, 0.5952380952380952, 'x[3] <= -0.062\nsquared_error = 486.139\nsamples = 6\nvalue = 92.833'),
#  Text(0.3953610964681075, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 55.0'),
#  Text(0.3995782814971007, 0.5476190476190477, 'x[0] <= -0.044\nsquared_error = 239.84\nsamples = 5\nvalue = 100.4'),
#  Text(0.3953610964681075, 0.5, 'x[3] <= -0.026\nsquared_error = 169.0\nsamples = 2\nvalue = 116.0'),
#  Text(0.39325250395361094, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 103.0'),
#  Text(0.3974696889826041, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 129.0'),
#  Text(0.4037954665260938, 0.5, 'x[8] <= -0.044\nsquared_error = 16.667\nsamples = 3\nvalue = 90.0'),
#  Text(0.40168687401159725, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 95.0'),
#  Text(0.4059040590405904, 0.4523809523809524, 'x[9] <= 0.001\nsquared_error = 6.25\nsamples = 2\nvalue = 87.5'),
#  Text(0.4037954665260938, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 90.0'),
#  Text(0.408012651555087, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 85.0'),
#  Text(0.41222983658408013, 0.5952380952380952, 'x[5] <= 0.008\nsquared_error = 644.667\nsamples = 3\nvalue = 148.0'),
#  Text(0.41012124406958356, 0.5476190476190477, 'x[0] <= 0.02\nsquared_error = 100.0\nsamples = 2\nvalue = 131.0'),
#  Text(0.408012651555087, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 121.0'),
#  Text(0.41222983658408013, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 141.0'),
#  Text(0.4143384290985767, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 182.0'),
#  Text(0.4164470216130733, 0.6904761904761905, 'x[9] <= -0.045\nsquared_error = 137.556\nsamples = 3\nvalue = 85.333'),
#  Text(0.4143384290985767, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.41855561412756986, 0.6428571428571429, 'x[6] <= -0.012\nsquared_error = 6.25\nsamples = 2\nvalue = 93.5'),
#  Text(0.4164470216130733, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 91.0'),
#  Text(0.42066420664206644, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 96.0'),
#  Text(0.4517659462308909, 0.7857142857142857, 'x[2] <= 0.039\nsquared_error = 5032.449\nsamples = 19\nvalue = 180.842'),
#  Text(0.4385872430152873, 0.7380952380952381, 'x[5] <= 0.013\nsquared_error = 3309.556\nsamples = 9\nvalue = 140.333'),
#  Text(0.43120716921454927, 0.6904761904761905, 'x[9] <= -0.007\nsquared_error = 1484.889\nsamples = 6\nvalue = 108.333'),
#  Text(0.4269899841855561, 0.6428571428571429, 'x[2] <= 0.032\nsquared_error = 81.0\nsamples = 2\nvalue = 61.0'),
#  Text(0.4248813916710596, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 52.0'),
#  Text(0.4290985767000527, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 70.0'),
#  Text(0.4354243542435424, 0.6428571428571429, 'x[4] <= -0.085\nsquared_error = 506.5\nsamples = 4\nvalue = 132.0'),
#  Text(0.43331576172904585, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.437532946758039, 0.5952380952380952, 'x[8] <= -0.026\nsquared_error = 33.556\nsamples = 3\nvalue = 119.333'),
#  Text(0.4354243542435424, 0.5476190476190477, 'x[9] <= 0.011\nsquared_error = 6.25\nsamples = 2\nvalue = 115.5'),
#  Text(0.43331576172904585, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 113.0'),
#  Text(0.437532946758039, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 118.0'),
#  Text(0.4396415392725356, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 127.0'),
#  Text(0.4459673168160253, 0.6904761904761905, 'x[2] <= 0.026\nsquared_error = 814.889\nsamples = 3\nvalue = 204.333'),
#  Text(0.44385872430152873, 0.6428571428571429, 'x[0] <= 0.033\nsquared_error = 42.25\nsamples = 2\nvalue = 184.5'),
#  Text(0.44175013178703215, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 191.0'),
#  Text(0.4459673168160253, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.4480759093305219, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 244.0'),
#  Text(0.46494464944649444, 0.7380952380952381, 'x[4] <= -0.02\nsquared_error = 3777.01\nsamples = 10\nvalue = 217.3'),
#  Text(0.4565102793885082, 0.6904761904761905, 'x[9] <= -0.014\nsquared_error = 222.688\nsamples = 4\nvalue = 275.75'),
#  Text(0.45229309435951504, 0.6428571428571429, 'x[4] <= -0.028\nsquared_error = 4.0\nsamples = 2\nvalue = 261.0'),
#  Text(0.45018450184501846, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 259.0'),
#  Text(0.4544016868740116, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 263.0'),
#  Text(0.46072746441750134, 0.6428571428571429, 'x[8] <= -0.023\nsquared_error = 6.25\nsamples = 2\nvalue = 290.5'),
#  Text(0.45861887190300477, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 293.0'),
#  Text(0.4628360569319979, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 288.0'),
#  Text(0.47337901950448075, 0.6904761904761905, 'x[5] <= 0.017\nsquared_error = 2350.556\nsamples = 6\nvalue = 178.333'),
#  Text(0.4691618344754876, 0.6428571428571429, 'x[8] <= -0.029\nsquared_error = 752.889\nsamples = 3\nvalue = 138.333'),
#  Text(0.467053241960991, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 175.0'),
#  Text(0.47127042698998417, 0.5952380952380952, 'x[9] <= 0.047\nsquared_error = 121.0\nsamples = 2\nvalue = 120.0'),
#  Text(0.4691618344754876, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 109.0'),
#  Text(0.47337901950448075, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 131.0'),
#  Text(0.4775962045334739, 0.6428571428571429, 'x[5] <= 0.03\nsquared_error = 748.222\nsamples = 3\nvalue = 218.333'),
#  Text(0.4754876120189773, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 257.0'),
#  Text(0.4797047970479705, 0.5952380952380952, 'x[4] <= 0.031\nsquared_error = 1.0\nsamples = 2\nvalue = 199.0'),
#  Text(0.4775962045334739, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 200.0'),
#  Text(0.48181338956246705, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.7551880848049551, 0.9285714285714286, 'x[2] <= 0.015\nsquared_error = 5135.611\nsamples = 224\nvalue = 193.152'),
#  Text(0.6416574175507379, 0.9523809523809523, '  False'),
#  Text(0.5967049123616236, 0.8809523809523809, 'x[2] <= -0.022\nsquared_error = 4095.838\nsamples = 116\nvalue = 162.681'),
#  Text(0.5251054296257248, 0.8333333333333334, 'x[4] <= -0.052\nsquared_error = 2869.499\nsamples = 42\nvalue = 137.69'),
#  Text(0.48919346336320507, 0.7857142857142857, 'x[5] <= -0.069\nsquared_error = 1904.139\nsamples = 6\nvalue = 193.833'),
#  Text(0.4849762783342119, 0.7380952380952381, 'x[3] <= -0.056\nsquared_error = 390.889\nsamples = 3\nvalue = 167.667'),
#  Text(0.48286768581971534, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 140.0'),
#  Text(0.4870848708487085, 0.6904761904761905, 'x[5] <= -0.075\nsquared_error = 12.25\nsamples = 2\nvalue = 181.5'),
#  Text(0.4849762783342119, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.48919346336320507, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 185.0'),
#  Text(0.4934106483921982, 0.7380952380952381, 'x[2] <= -0.024\nsquared_error = 2048.0\nsamples = 3\nvalue = 220.0'),
#  Text(0.49130205587770165, 0.6904761904761905, 'squared_error = 0.0\nsamples = 2\nvalue = 252.0'),
#  Text(0.4955192409066948, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 156.0'),
#  Text(0.5610173958882446, 0.7857142857142857, 'x[9] <= 0.042\nsquared_error = 2417.5\nsamples = 36\nvalue = 128.333'),
#  Text(0.5369003690036901, 0.7380952380952381, 'x[8] <= 0.027\nsquared_error = 2266.21\nsamples = 30\nvalue = 119.3'),
#  Text(0.5092250922509225, 0.6904761904761905, 'x[2] <= -0.049\nsquared_error = 1735.556\nsamples = 21\nvalue = 105.667'),
#  Text(0.4934106483921982, 0.6428571428571429, 'x[6] <= -0.029\nsquared_error = 2180.531\nsamples = 7\nvalue = 137.429'),
#  Text(0.4881391671059568, 0.5952380952380952, 'x[4] <= -0.026\nsquared_error = 676.0\nsamples = 2\nvalue = 188.0'),
#  Text(0.4860305745914602, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 162.0'),
#  Text(0.49024775962045336, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 214.0'),
#  Text(0.49868212967843967, 0.5952380952380952, 'x[8] <= 0.001\nsquared_error = 1350.16\nsamples = 5\nvalue = 117.2'),
#  Text(0.4944649446494465, 0.5476190476190477, 'x[3] <= 0.015\nsquared_error = 72.25\nsamples = 2\nvalue = 161.5'),
#  Text(0.49235635213494994, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 153.0'),
#  Text(0.4965735371639431, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 170.0'),
#  Text(0.5028993147074328, 0.5476190476190477, 'x[8] <= 0.018\nsquared_error = 21.556\nsamples = 3\nvalue = 87.667'),
#  Text(0.5007907221929362, 0.5, 'x[0] <= -0.035\nsquared_error = 2.25\nsamples = 2\nvalue = 84.5'),
#  Text(0.49868212967843967, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 86.0'),
# ...
#  Text(0.838165524512388, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(0.8423827095413812, 0.5952380952380952, 'x[2] <= 0.057\nsquared_error = 900.0\nsamples = 2\nvalue = 162.0'),
#  Text(0.8402741170268846, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 192.0'),
#  Text(0.8444913020558777, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 132.0'),
#  Text(0.8228782287822878, 0.7380952380952381, 'x[3] <= -0.025\nsquared_error = 533.556\nsamples = 3\nvalue = 284.333'),
#  Text(0.8207696362677912, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 317.0'),
#  Text(0.8249868212967844, 0.6904761904761905, 'squared_error = 0.0\nsamples = 2\nvalue = 268.0'),
#  Text(0.9049486030574592, 0.7857142857142857, 'x[8] <= 0.074\nsquared_error = 1825.77\nsamples = 44\nvalue = 231.341'),
#  Text(0.8889694254085398, 0.7380952380952381, 'x[3] <= 0.096\nsquared_error = 1763.842\nsamples = 36\nvalue = 224.639'),
#  Text(0.8707169214549288, 0.6904761904761905, 'x[9] <= -0.02\nsquared_error = 1619.152\nsamples = 32\nvalue = 218.688'),
#  Text(0.8581971534001054, 0.6428571428571429, 'x[6] <= 0.03\nsquared_error = 483.222\nsamples = 6\nvalue = 246.333'),
#  Text(0.8529256721138639, 0.5952380952380952, 'x[1] <= 0.003\nsquared_error = 110.25\nsamples = 4\nvalue = 232.5'),
#  Text(0.8487084870848709, 0.5476190476190477, 'x[6] <= 0.016\nsquared_error = 36.0\nsamples = 2\nvalue = 242.0'),
#  Text(0.8465998945703743, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 248.0'),
#  Text(0.8508170795993675, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 236.0'),
#  Text(0.8571428571428571, 0.5476190476190477, 'x[4] <= -0.029\nsquared_error = 4.0\nsamples = 2\nvalue = 223.0'),
#  Text(0.8550342646283605, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 225.0'),
#  Text(0.8592514496573537, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 221.0'),
#  Text(0.8634686346863468, 0.5952380952380952, 'x[8] <= 0.056\nsquared_error = 81.0\nsamples = 2\nvalue = 274.0'),
#  Text(0.8613600421718502, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.8655772272008434, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 283.0'),
#  Text(0.8832366895097522, 0.6428571428571429, 'x[2] <= 0.018\nsquared_error = 1664.213\nsamples = 26\nvalue = 212.308'),
#  Text(0.8719030047443331, 0.5952380952380952, 'x[2] <= 0.017\nsquared_error = 889.556\nsamples = 3\nvalue = 174.667'),
#  Text(0.8697944122298366, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 212.0'),
#  Text(0.8740115972588297, 0.5476190476190477, 'x[1] <= 0.003\nsquared_error = 289.0\nsamples = 2\nvalue = 156.0'),
#  Text(0.8719030047443331, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 173.0'),
#  Text(0.8761201897733263, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 139.0'),
#  Text(0.8945703742751713, 0.5952380952380952, 'x[9] <= 0.088\nsquared_error = 1556.344\nsamples = 23\nvalue = 217.217'),
#  Text(0.8924617817606747, 0.5476190476190477, 'x[9] <= 0.038\nsquared_error = 1443.134\nsamples = 22\nvalue = 220.045'),
#  Text(0.8803373748023194, 0.5, 'x[5] <= -0.048\nsquared_error = 1422.984\nsamples = 16\nvalue = 211.875'),
#  Text(0.8782287822878229, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.882445967316816, 0.4523809523809524, 'x[5] <= 0.009\nsquared_error = 1178.062\nsamples = 15\nvalue = 207.267'),
#  Text(0.875065893516078, 0.40476190476190477, 'x[3] <= 0.025\nsquared_error = 395.143\nsamples = 7\nvalue = 186.0'),
#  Text(0.8729573010015814, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 151.0'),
#  Text(0.8771744860305746, 0.35714285714285715, 'x[6] <= 0.05\nsquared_error = 222.806\nsamples = 6\nvalue = 191.833'),
#  Text(0.875065893516078, 0.30952380952380953, 'x[0] <= 0.036\nsquared_error = 107.2\nsamples = 5\nvalue = 197.0'),
#  Text(0.8729573010015814, 0.2619047619047619, 'x[0] <= -0.0\nsquared_error = 21.188\nsamples = 4\nvalue = 201.75'),
#  Text(0.8708487084870848, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 195.0'),
#  Text(0.875065893516078, 0.21428571428571427, 'x[0] <= 0.02\nsquared_error = 8.0\nsamples = 3\nvalue = 204.0'),
#  Text(0.8729573010015814, 0.16666666666666666, 'squared_error = 0.0\nsamples = 2\nvalue = 202.0'),
#  Text(0.8771744860305746, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 208.0'),
#  Text(0.8771744860305746, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 178.0'),
#  Text(0.8792830785450712, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 166.0'),
#  Text(0.889826041117554, 0.40476190476190477, 'x[4] <= 0.025\nsquared_error = 1121.109\nsamples = 8\nvalue = 225.875'),
#  Text(0.8856088560885609, 0.35714285714285715, 'x[3] <= 0.06\nsquared_error = 330.688\nsamples = 4\nvalue = 252.25'),
#  Text(0.8835002635740643, 0.30952380952380953, 'x[2] <= 0.019\nsquared_error = 210.889\nsamples = 3\nvalue = 244.667'),
#  Text(0.8813916710595677, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 265.0'),
#  Text(0.8856088560885609, 0.2619047619047619, 'x[6] <= -0.003\nsquared_error = 6.25\nsamples = 2\nvalue = 234.5'),
#  Text(0.8835002635740643, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(0.8877174486030575, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 237.0'),
#  Text(0.8877174486030575, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 275.0'),
#  Text(0.8940432261465472, 0.35714285714285715, 'x[9] <= 0.003\nsquared_error = 520.25\nsamples = 4\nvalue = 199.5'),
#  Text(0.8919346336320506, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 163.0'),
#  Text(0.8961518186610438, 0.30952380952380953, 'x[3] <= 0.043\nsquared_error = 101.556\nsamples = 3\nvalue = 211.667'),
#  Text(0.8940432261465472, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 198.0'),
#  Text(0.8982604111755403, 0.2619047619047619, 'x[2] <= 0.046\nsquared_error = 12.25\nsamples = 2\nvalue = 218.5'),
#  Text(0.8961518186610438, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 222.0'),
#  Text(0.9003690036900369, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 215.0'),
#  Text(0.9045861887190301, 0.5, 'x[2] <= 0.054\nsquared_error = 844.139\nsamples = 6\nvalue = 241.833'),
#  Text(0.9024775962045335, 0.4523809523809524, 'x[8] <= 0.029\nsquared_error = 264.8\nsamples = 5\nvalue = 253.0'),
#  Text(0.9003690036900369, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.9045861887190301, 0.40476190476190477, 'x[5] <= -0.04\nsquared_error = 86.0\nsamples = 4\nvalue = 246.0'),
#  Text(0.9024775962045335, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 232.0'),
#  Text(0.9066947812335266, 0.35714285714285715, 'x[4] <= 0.091\nsquared_error = 27.556\nsamples = 3\nvalue = 250.667'),
#  Text(0.9045861887190301, 0.30952380952380953, 'x[5] <= 0.025\nsquared_error = 1.0\nsamples = 2\nvalue = 247.0'),
#  Text(0.9024775962045335, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 246.0'),
#  Text(0.9066947812335266, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 248.0'),
#  Text(0.9088033737480232, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(0.9066947812335266, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 186.0'),
#  Text(0.8966789667896679, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 155.0'),
#  Text(0.9072219293621507, 0.6904761904761905, 'x[8] <= 0.052\nsquared_error = 371.188\nsamples = 4\nvalue = 272.25'),
#  Text(0.9051133368476542, 0.6428571428571429, 'x[4] <= 0.036\nsquared_error = 114.667\nsamples = 3\nvalue = 282.0'),
#  Text(0.9030047443331576, 0.5952380952380952, 'x[4] <= 0.005\nsquared_error = 25.0\nsamples = 2\nvalue = 275.0'),
#  Text(0.900896151818661, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 280.0'),
#  Text(0.9051133368476542, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 270.0'),
#  Text(0.9072219293621507, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 296.0'),
#  Text(0.9093305218766473, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 243.0'),
#  Text(0.9209277807063785, 0.7380952380952381, 'x[6] <= -0.038\nsquared_error = 992.75\nsamples = 8\nvalue = 261.5'),
#  Text(0.915656299420137, 0.6904761904761905, 'x[9] <= 0.034\nsquared_error = 347.44\nsamples = 5\nvalue = 241.4'),
#  Text(0.9135477069056405, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 273.0'),
#  Text(0.9177648919346336, 0.6428571428571429, 'x[8] <= 0.116\nsquared_error = 122.25\nsamples = 4\nvalue = 233.5'),
#  Text(0.9135477069056405, 0.5952380952380952, 'x[5] <= 0.084\nsquared_error = 42.25\nsamples = 2\nvalue = 223.5'),
#  Text(0.9114391143911439, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 230.0'),
#  Text(0.915656299420137, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 217.0'),
#  Text(0.9219820769636268, 0.5952380952380952, 'x[4] <= 0.027\nsquared_error = 2.25\nsamples = 2\nvalue = 243.5'),
#  Text(0.9198734844491302, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.9240906694781233, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 245.0'),
#  Text(0.9261992619926199, 0.6904761904761905, 'x[8] <= 0.075\nsquared_error = 272.667\nsamples = 3\nvalue = 295.0'),
#  Text(0.9240906694781233, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 272.0'),
#  Text(0.9283078545071165, 0.6428571428571429, 'x[5] <= -0.026\nsquared_error = 12.25\nsamples = 2\nvalue = 306.5'),
#  Text(0.9261992619926199, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 303.0'),
#  Text(0.9304164470216131, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 310.0'),
#  Text(0.9685028993147075, 0.8333333333333334, 'x[5] <= 0.022\nsquared_error = 2133.016\nsamples = 31\nvalue = 268.871'),
#  Text(0.9565102793885082, 0.7857142857142857, 'x[8] <= 0.032\nsquared_error = 1073.612\nsamples = 19\nvalue = 290.421'),
#  Text(0.9462308908803374, 0.7380952380952381, 'x[6] <= -0.014\nsquared_error = 999.265\nsamples = 7\nvalue = 315.857'),
#  Text(0.940959409594096, 0.6904761904761905, 'x[2] <= 0.108\nsquared_error = 72.56\nsamples = 5\nvalue = 335.2'),
#  Text(0.9367422245651028, 0.6428571428571429, 'x[3] <= 0.048\nsquared_error = 30.25\nsamples = 2\nvalue = 326.5'),
#  Text(0.9346336320506062, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 332.0'),
#  Text(0.9388508170795994, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 321.0'),
#  Text(0.9451765946230891, 0.6428571428571429, 'x[4] <= -0.03\nsquared_error = 16.667\nsamples = 3\nvalue = 341.0'),
#  Text(0.9430680021085925, 0.5952380952380952, 'x[4] <= -0.043\nsquared_error = 6.25\nsamples = 2\nvalue = 338.5'),
#  Text(0.940959409594096, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 341.0'),
#  Text(0.9451765946230891, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 336.0'),
#  Text(0.9472851871375857, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 346.0'),
#  Text(0.9515023721665788, 0.6904761904761905, 'x[3] <= 0.084\nsquared_error = 42.25\nsamples = 2\nvalue = 267.5'),
#  Text(0.9493937796520823, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 261.0'),
#  Text(0.9536109646810754, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 274.0'),
#  Text(0.966789667896679, 0.7380952380952381, 'x[7] <= 0.037\nsquared_error = 519.41\nsamples = 12\nvalue = 275.583'),
#  Text(0.9646810753821824, 0.6904761904761905, 'x[5] <= 0.007\nsquared_error = 260.231\nsamples = 11\nvalue = 280.636'),
#  Text(0.9588824459673169, 0.6428571428571429, 'x[0] <= 0.04\nsquared_error = 51.688\nsamples = 8\nvalue = 271.75'),
#  Text(0.9536109646810754, 0.5952380952380952, 'x[5] <= -0.028\nsquared_error = 48.556\nsamples = 6\nvalue = 269.667'),
#  Text(0.9493937796520823, 0.5476190476190477, 'x[2] <= 0.102\nsquared_error = 6.25\nsamples = 2\nvalue = 260.5'),
#  Text(0.9472851871375857, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 263.0'),
#  Text(0.9515023721665788, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 258.0'),
#  Text(0.9578281497100686, 0.5476190476190477, 'x[4] <= -0.008\nsquared_error = 6.688\nsamples = 4\nvalue = 274.25'),
#  Text(0.955719557195572, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 270.0'),
#  Text(0.9599367422245652, 0.5, 'x[2] <= 0.071\nsquared_error = 0.889\nsamples = 3\nvalue = 275.667'),
#  Text(0.9578281497100686, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 277.0'),
#  Text(0.9620453347390617, 0.4523809523809524, 'squared_error = 0.0\nsamples = 2\nvalue = 275.0'),
#  Text(0.9641539272535582, 0.5952380952380952, 'x[8] <= 0.035\nsquared_error = 9.0\nsamples = 2\nvalue = 278.0'),
#  Text(0.9620453347390617, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 275.0'),
#  Text(0.9662625197680548, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 281.0'),
#  Text(0.9704797047970479, 0.6428571428571429, 'x[2] <= 0.08\nsquared_error = 44.222\nsamples = 3\nvalue = 304.333'),
#  Text(0.9683711122825513, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 295.0'),
#  Text(0.9725882973115445, 0.5952380952380952, 'x[3] <= 0.092\nsquared_error = 1.0\nsamples = 2\nvalue = 309.0'),
#  Text(0.9704797047970479, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 310.0'),
#  Text(0.9746968898260411, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 308.0'),
#  Text(0.9688982604111755, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 220.0'),
#  Text(0.9804955192409067, 0.7857142857142857, 'x[4] <= 0.018\nsquared_error = 1910.854\nsamples = 12\nvalue = 234.75'),
#  Text(0.9783869267264101, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 128.0'),
#  Text(0.9826041117554033, 0.7380952380952381, 'x[6] <= -0.06\nsquared_error = 954.43\nsamples = 11\nvalue = 244.455'),
#  Text(0.9804955192409067, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 306.0'),
#  Text(0.9847127042698999, 0.6904761904761905, 'x[4] <= 0.023\nsquared_error = 633.21\nsamples = 10\nvalue = 238.3'),
#  Text(0.9789140748550342, 0.6428571428571429, 'x[6] <= -0.042\nsquared_error = 56.25\nsamples = 2\nvalue = 271.5'),
#  Text(0.9768054823405377, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 264.0'),
#  Text(0.9810226673695308, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 279.0'),
#  Text(0.9905113336847654, 0.6428571428571429, 'x[9] <= 0.044\nsquared_error = 433.0\nsamples = 8\nvalue = 230.0'),
#  Text(0.985239852398524, 0.5952380952380952, 'x[3] <= 0.092\nsquared_error = 41.04\nsamples = 5\nvalue = 241.4'),
#  Text(0.9831312598840274, 0.5476190476190477, 'x[6] <= -0.001\nsquared_error = 16.188\nsamples = 4\nvalue = 238.75'),
#  Text(0.9789140748550342, 0.5, 'x[7] <= 0.071\nsquared_error = 0.25\nsamples = 2\nvalue = 242.5'),
#  Text(0.9768054823405377, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 242.0'),
#  Text(0.9810226673695308, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 243.0'),
#  Text(0.9873484449130205, 0.5, 'x[3] <= 0.041\nsquared_error = 4.0\nsamples = 2\nvalue = 235.0'),
#  Text(0.985239852398524, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 237.0'),
#  Text(0.9894570374275171, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 233.0'),
#  Text(0.9873484449130205, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 252.0'),
#  Text(0.9957828149710068, 0.5952380952380952, 'x[0] <= 0.005\nsquared_error = 508.667\nsamples = 3\nvalue = 211.0'),
#  Text(0.9936742224565103, 0.5476190476190477, 'x[3] <= -0.037\nsquared_error = 42.25\nsamples = 2\nvalue = 226.5'),
#  Text(0.9915656299420137, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 220.0'),
#  Text(0.9957828149710068, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 233.0'),
#  Text(0.9978914074855034, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 180.0')]

# %% [markdown]
# #### graphviz를 사용한 시각화

# %%
dot_data = tree.export_graphviz(decision_tree=model,
                                feature_names=diabetes.feature_names,
                                filled=True, rounded=True,
                                special_characters=True)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# #### 회귀식 시각화

# %%
plt.figure(figsize=(16, 8))

for pairidx, pair in enumerate([0, 2, 3]):
  X = diabetes.data[:, pair].reshape(-1, 1)
  y = diabetes.target

  model = DecisionTreeRegressor()
  model.fit(X, y)

  X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
  predict = model.predict(X_test)

  plt.subplot(1, 3, pairidx + 1)
  plt.scatter(X, y, s=20, edgecolors='k',
              c='darkorange', label='data')
  plt.plot(X_test, predict, color='royalblue', linewidth=2)
  plt.xlabel(diabetes.feature_names[pair])
  plt
# Out:
# <ipython-input-44-af58eb9118c8>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
# <ipython-input-44-af58eb9118c8>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
# <ipython-input-44-af58eb9118c8>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]

# %% [markdown]
# #### 하이퍼파파미터를 변경하면서 회귀식 시각화

# %%
plt.figure(figsize=(16, 8))

for pairidx, pair in enumerate([0, 2, 3]):
  X = diabetes.data[:, pair].reshape(-1, 1)
  y = diabetes.target

  model = DecisionTreeRegressor(max_depth=3)
  model.fit(X, y)

  X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
  predict = model.predict(X_test)

  plt.subplot(1, 3, pairidx + 1)
  plt.scatter(X, y, s=20, edgecolors='k',
              c='darkorange', label='data')
  plt.plot(X_test, predict, color='royalblue', linewidth=2)
  plt.xlabel(diabetes.feature_names[pair])
  plt
# Out:
# <ipython-input-45-be4ea012a4f4>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
# <ipython-input-45-be4ea012a4f4>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
# <ipython-input-45-be4ea012a4f4>:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_test = np.arange(min(X), max(X), 0.1)[:, np.newaxis]
